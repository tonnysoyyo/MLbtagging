# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

file_path = "outputEta_Phi.csv"  # Reemplaza con la ruta de tu archivo
df = pd.read_csv(file_path, delimiter='\s+', header=0)

# Muestra las primeras filas del DataFrame
df
# Out:
#           Jet_Eta   Jet_Phi  Particle_Eta  Particle_Phi
# 0       -2.241420 -2.308470     999.90000      0.000000
# 1       -1.107460  3.066420    -999.90000      0.000000
# 2       -1.293880  1.300320      -5.06071      0.739460
# 3        0.962724  1.231660      -3.54499      2.269740
# 4       -4.749430  1.324970      -4.95687     -0.871848
# ...           ...       ...           ...           ...
# 1249995 -1.836390 -1.855760      -1.01609     -0.638549
# 1249996 -2.671190  0.536776      -5.47956      2.503040
# 1249997  0.359637  0.960008      -1.12051      2.504240
# 1249998  3.965720  0.368665       1.07668     -1.651790
# 1249999  1.703680  2.908430       2.20035     -1.030980
#
# [1250000 rows x 4 columns]

# %%
# Extrae la primera columna (suponiendo que se llama "Jet_Eta")
jet_eta_column = df.iloc[:, 0]

# Crear la figura y el eje
fig, ax = plt.subplots()

# Histograma
n, bins, patches = ax.hist(jet_eta_column, bins=500, edgecolor='blue', color='white')

# Ajustar el estilo
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Título y etiquetas
ax.set_title('Jet.Eta')
ax.set_xlabel('Jet.Eta')

# Mostrar información en la parte superior derecha
entries = len(jet_eta_column)
mean = np.mean(jet_eta_column)
std_dev = np.std(jet_eta_column)

textstr = '\n'.join((
    r'Entries %d' % (entries, ),
    r'Mean %.6f' % (mean, ),
    r'Std Dev %.3f' % (std_dev, )))

# Propiedades del texto
props = dict(boxstyle='round', facecolor='white', alpha=0.5)

# Posición del texto
ax.text(0.75, 0.95, textstr, transform=ax.transAxes, fontsize=10,
        verticalalignment='top', bbox=props)

plt.show()

# %%
# Extrae la primera columna (suponiendo que se llama "Jet_Eta")
jet_phi_column = df.iloc[:, 1]

# Crear la figura y el eje
fig, ax = plt.subplots()

# Histograma
n, bins, patches = ax.hist(jet_phi_column, bins=900, edgecolor='blue', color='white')

# Ajustar el estilo
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Título y etiquetas
ax.set_title('Jet.Phi')
ax.set_xlabel('Jet.Phi')

# Mostrar información en la parte superior derecha
entries = len(jet_phi_column)
mean = np.mean(jet_phi_column)
std_dev = np.std(jet_phi_column)

textstr = '\n'.join((
    r'Entries %d' % (entries, ),
    r'Mean %.6f' % (mean, ),
    r'Std Dev %.3f' % (std_dev, )))

# Propiedades del texto
props = dict(boxstyle='round', facecolor='white', alpha=0.5)

# Posición del texto
ax.text(0.75, 0.95, textstr, transform=ax.transAxes, fontsize=10,
        verticalalignment='top', bbox=props)

plt.show()

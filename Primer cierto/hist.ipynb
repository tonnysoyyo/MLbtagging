# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path = "output0.1.csv"  # Reemplaza con la ruta de tu archivo
df = pd.read_csv(file_path, delimiter='\s+', header=0)

# Muestra las primeras filas del DataFrame
df
# Out:
#           Jet_Eta   Jet_Phi  Particle_Eta  Particle_Phi
# 0       -2.241420 -2.308470     999.90000      0.000000
# 1       -1.107460  3.066420    -999.90000      0.000000
# 2       -1.293880  1.300320      -5.06071      0.739460
# 3        0.962724  1.231660      -3.54499      2.269740
# 4       -4.749430  1.324970      -4.95687     -0.871848
# ...           ...       ...           ...           ...
# 1249995 -1.836390 -1.855760      -1.01609     -0.638549
# 1249996 -2.671190  0.536776      -5.47956      2.503040
# 1249997  0.359637  0.960008      -1.12051      2.504240
# 1249998  3.965720  0.368665       1.07668     -1.651790
# 1249999  1.703680  2.908430       2.20035     -1.030980
#
# [1250000 rows x 4 columns]

# %%
# Extrae la primera columna (suponiendo que se llama "Jet_Eta")
jet_eta_column = df.iloc[:, 0]

# Calcula el número de entradas, la media y la desviación estándar
num_entries = len(jet_eta_column)
mean_value = jet_eta_column.mean()
std_deviation = jet_eta_column.std()

fig, ax = plt.subplots(figsize=(10, 6))

# Grafica el histograma de la primera columna
plt.hist(jet_eta_column, bins=5000, edgecolor='blue', color='white', linewidth=1.2)  # Personalización del contorno y relleno
plt.xlabel('Jet_Eta', fontsize=14)  # Ajusta el tamaño de la fuente del eje x
plt.ylabel('Frecuencia', fontsize=14)  # Ajusta el tamaño de la fuente del eje y
plt.title('Histograma de Jet_Eta', fontsize=16)  # Ajusta el tamaño de la fuente del título

# Agrega información al gráfico con más espacio
plt.text(0.02, 0.92, f'Entradas: {num_entries}', transform=ax.transAxes, fontsize=12)
plt.text(0.02, 0.88, f'Media: {mean_value:.6f}', transform=ax.transAxes, fontsize=12)
plt.text(0.02, 0.84, f'Des Est: {std_deviation:.6f}', transform=ax.transAxes, fontsize=12)

plt.tight_layout()  # Ajusta automáticamente el espaciado para evitar superposiciones

plt.show()

# %%
# Extrae la primera columna (suponiendo que se llama "Jet_Phi")
jet_phi_column = df.iloc[:, 1]

# Calcula el número de entradas, la media y la desviación estándar
num_entries = len(jet_phi_column)
mean_value = jet_phi_column.mean()
std_deviation = jet_phi_column.std()

fig, ax = plt.subplots(figsize=(10, 6))

# Grafica el histograma de la primera columna
plt.hist(jet_phi_column, bins=5000, edgecolor='blue', color='white', linewidth=1.2)  # Personalización del contorno y relleno
plt.xlabel('Jet_Phi', fontsize=14)  # Ajusta el tamaño de la fuente del eje x
plt.ylabel('Frecuencia', fontsize=14)  # Ajusta el tamaño de la fuente del eje y
plt.title('Histograma de Jet_Phi', fontsize=16)  # Ajusta el tamaño de la fuente del título

# Agrega información al gráfico con más espacio
plt.text(0.02, 0.92, f'Entradas: {num_entries}', transform=ax.transAxes, fontsize=12)
plt.text(0.02, 0.88, f'Media: {mean_value:.6f}', transform=ax.transAxes, fontsize=12)
plt.text(0.02, 0.84, f'Des Est: {std_deviation:.6f}', transform=ax.transAxes, fontsize=12)

plt.tight_layout()  # Ajusta automáticamente el espaciado para evitar superposiciones

plt.show()
